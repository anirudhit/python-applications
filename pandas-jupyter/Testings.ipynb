# %%
import pandas

# %%
df=pandas.read_csv("countries.csv")
df
# Out:
#        1                               Andorra  AD
# 0      2                  United Arab Emirates  AE
# 1      3                           Afghanistan  AF
# 2      4                   Antigua and Barbuda  AG
# 3      5                              Anguilla  AI
# 4      6                               Albania  AL
# 5      7                               Armenia  AM
# 6      8                  Netherlands Antilles  AN
# 7      9                                Angola  AO
# 8     10                            Antarctica  AQ
# 9     11                             Argentina  AR
# 10    12                        American Samoa  AS
# 11    13                               Austria  AT
# 12    14                             Australia  AU
# 13    15                                 Aruba  AW
# 14    16                         Aland Islands  AX
# 15    17                            Azerbaijan  AZ
# 16    18                Bosnia and Herzegovina  BA
# ...
